# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
kings_data = pd.read_csv("../Resources/cleaned_df.csv")

# %%
kings_data.head()
# Out:
#    YEAR             PLAYER                   TEAM    SALARY  AGE  GP   W  L  \
# 0  2015      Stephen Curry  Golden State Warriors  11370786   28  79  71  8
# 1  2015   Shaun Livingston  Golden State Warriors   5543725   30  78  69  9
# 2  2015  Marreese Speights  Golden State Warriors   3815000   28  72  64  8
# 3  2015    Leandro Barbosa  Golden State Warriors   2500000   33  68  60  8
# 4  2015      Klay Thompson  Golden State Warriors  15501000   26  80  71  9
#
#     MIN   PTS  ...  AST  TOV  STL  BLK   PF    FP  DD2  TD3   +/-   RK
# 0  34.2  30.1  ...  6.7  3.3  2.1  0.2  2.0  50.3   15    2  12.9   61
# 1  19.5   6.3  ...  3.0  1.0  0.7  0.3  1.8  15.6    0    0   2.7  132
# 2  11.6   7.1  ...  0.8  0.9  0.3  0.5  1.6  13.7    1    0   0.2  183
# 3  15.9   6.4  ...  1.2  0.8  0.6  0.1  1.6  11.8    0    0   0.6  243
# 4  33.3  22.1  ...  2.1  1.7  0.8  0.6  1.9  32.2    0    0  10.5   31
#
# [5 rows x 32 columns]

# %%
kings_cleansed_df = kings_data.loc[kings_data['TEAM']== 'Sacramento Kings']
kings_cleansed_df = kings_cleansed_df.loc[kings_cleansed_df['YEAR']== 2015]
kings_cleansed_df
# Out:
#      YEAR               PLAYER              TEAM    SALARY  AGE  GP   W   L  \
# 225  2015  Willie Cauley-Stein  Sacramento Kings   3398280   22  66  26  40
# 226  2015           Seth Curry  Sacramento Kings    947276   25  44  17  27
# 227  2015             Rudy Gay  Sacramento Kings  12403101   29  70  29  41
# 228  2015          Rajon Rondo  Sacramento Kings   9500000   30  72  29  43
# 229  2015           Quincy Acy  Sacramento Kings    981348   25  59  21  38
# 230  2015          Omri Casspi  Sacramento Kings   2836186   28  69  27  42
# 231  2015      Marco Belinelli  Sacramento Kings   6060606   30  68  27  41
# 232  2015         Kosta Koufos  Sacramento Kings   7700000   27  78  32  46
# 233  2015       James Anderson  Sacramento Kings   1015421   27  51  19  32
# 234  2015        Eric Moreland  Sacramento Kings    845059   24   8   1   7
# 235  2015           Duje Dukan  Sacramento Kings    525093   24   1   0   1
# 236  2015     DeMarcus Cousins  Sacramento Kings  15851950   25  65  29  36
# 237  2015      Darren Collison  Sacramento Kings   5013559   28  74  29  45
# 238  2015         Caron Butler  Sacramento Kings   1449187   36  17   2  15
# 239  2015         Ben McLemore  Sacramento Kings   3156600   23  68  28  40
#
#       MIN   PTS  ...   AST  TOV  STL  BLK   PF    FP  DD2  TD3  +/-   RK
# 225  21.4   7.0  ...   0.6  0.7  0.7  1.0  2.2  18.7    3    0 -1.2  197
# 226  15.7   6.8  ...   1.5  0.8  0.5  0.1  0.9  11.6    1    0 -0.8  406
# 227  34.0  17.2  ...   1.7  2.0  1.4  0.7  2.6  32.1    7    0 -1.2   52
# 228  35.2  11.9  ...  11.7  3.9  2.0  0.1  2.4  39.1   37    6 -2.1   79
# 229  14.8   5.2  ...   0.5  0.5  0.5  0.4  1.7  12.0    0    0 -2.1  367
# 230  27.3  11.8  ...   1.4  1.4  0.8  0.2  2.2  22.8    6    0  0.1  229
# 231  24.6  10.2  ...   1.9  1.2  0.5  0.0  1.3  15.6    0    0 -2.7  122
# 232  19.0   6.8  ...   0.4  0.6  0.5  0.9  2.4  17.5    5    0 -2.9  100
# 233  14.1   3.5  ...   0.8  0.8  0.4  0.3  1.1   8.0    0    0 -1.6  355
# 234   5.9   1.0  ...   0.1  0.4  0.0  0.5  0.5   4.0    0    0  0.9  425
# 235  24.2   6.0  ...   1.0  0.0  1.0  0.0  2.0  15.3    0    0 -8.0  462
# 236  34.6  26.9  ...   3.3  3.8  1.6  1.4  3.6  50.7   47    1  0.6   27
# 237  30.0  14.0  ...   4.3  1.8  1.0  0.1  1.9  24.7    4    0 -0.9  147
# 238  10.3   3.7  ...   0.6  0.2  0.5  0.1  1.1   7.7    0    0 -2.4  306
# 239  21.2   7.8  ...   1.2  1.5  0.8  0.1  2.1  13.4    0    0  0.3  205
#
# [15 rows x 32 columns]

# %%
x_PTS = kings_cleansed_df['PTS']
y_Salary = kings_cleansed_df['SALARY']
plt.scatter(x_PTS,y_Salary,marker = 'o',edgecolors = 'blue')
plt.title("Points vs. Salary")
plt.xlabel("Points")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,20000000,1000000))
# Out:
# ([<matplotlib.axis.YTick at 0x1cd977b28d0>,
#   <matplotlib.axis.YTick at 0x1cd977b21d0>,
#   <matplotlib.axis.YTick at 0x1cd9771ac50>,
#   <matplotlib.axis.YTick at 0x1cd977c8eb8>,
#   <matplotlib.axis.YTick at 0x1cd977d63c8>,
#   <matplotlib.axis.YTick at 0x1cd977d6898>,
#   <matplotlib.axis.YTick at 0x1cd977d6e10>,
#   <matplotlib.axis.YTick at 0x1cd977dc3c8>,
#   <matplotlib.axis.YTick at 0x1cd977dc940>,
#   <matplotlib.axis.YTick at 0x1cd977dceb8>,
#   <matplotlib.axis.YTick at 0x1cd977d6978>,
#   <matplotlib.axis.YTick at 0x1cd977e4198>,
#   <matplotlib.axis.YTick at 0x1cd977e4710>,
#   <matplotlib.axis.YTick at 0x1cd977e4c88>,
#   <matplotlib.axis.YTick at 0x1cd977ec240>,
#   <matplotlib.axis.YTick at 0x1cd977ec7b8>,
#   <matplotlib.axis.YTick at 0x1cd977ecd30>,
#   <matplotlib.axis.YTick at 0x1cd977f42e8>,
#   <matplotlib.axis.YTick at 0x1cd977ec630>,
#   <matplotlib.axis.YTick at 0x1cd977e4668>],
#  <a list of 20 Text yticklabel objects>)

# %%
x_assists = kings_cleansed_df['AST']
y_salary = kings_cleansed_df['SALARY']
plt.scatter(x_assists,y_Salary,marker = 'o',edgecolors = 'red')
plt.title("Assists vs. Salary")
plt.xlabel("Assists")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,20000000,1000000))
# Out:
# ([<matplotlib.axis.YTick at 0x1cd974fdda0>,
#   <matplotlib.axis.YTick at 0x1cd974fd668>,
#   <matplotlib.axis.YTick at 0x1cd974f8630>,
#   <matplotlib.axis.YTick at 0x1cd975223c8>,
#   <matplotlib.axis.YTick at 0x1cd97522898>,
#   <matplotlib.axis.YTick at 0x1cd97522d68>,
#   <matplotlib.axis.YTick at 0x1cd975282e8>,
#   <matplotlib.axis.YTick at 0x1cd97528860>,
#   <matplotlib.axis.YTick at 0x1cd97528dd8>,
#   <matplotlib.axis.YTick at 0x1cd97528940>,
#   <matplotlib.axis.YTick at 0x1cd97522240>,
#   <matplotlib.axis.YTick at 0x1cd9752f630>,
#   <matplotlib.axis.YTick at 0x1cd9752fba8>,
#   <matplotlib.axis.YTick at 0x1cd97536160>,
#   <matplotlib.axis.YTick at 0x1cd975366d8>,
#   <matplotlib.axis.YTick at 0x1cd97536c50>,
#   <matplotlib.axis.YTick at 0x1cd9753c208>,
#   <matplotlib.axis.YTick at 0x1cd9753c780>,
#   <matplotlib.axis.YTick at 0x1cd97536550>,
#   <matplotlib.axis.YTick at 0x1cd9752f588>],
#  <a list of 20 Text yticklabel objects>)

# %%
x_three = kings_cleansed_df['3P%']
y_salary = kings_cleansed_df['SALARY']
plt.scatter(x_three,y_salary,marker = 'o',edgecolors = 'green')
plt.title("3P% vs. Salary")
plt.xlabel("3P%")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,20000000,1000000))
# Out:
# ([<matplotlib.axis.YTick at 0x1cd97833eb8>,
#   <matplotlib.axis.YTick at 0x1cd97833780>,
#   <matplotlib.axis.YTick at 0x1cd97824390>,
#   <matplotlib.axis.YTick at 0x1cd978574e0>,
#   <matplotlib.axis.YTick at 0x1cd978579b0>,
#   <matplotlib.axis.YTick at 0x1cd97857e80>,
#   <matplotlib.axis.YTick at 0x1cd9785e400>,
#   <matplotlib.axis.YTick at 0x1cd9785e978>,
#   <matplotlib.axis.YTick at 0x1cd9785eef0>,
#   <matplotlib.axis.YTick at 0x1cd9785efd0>,
#   <matplotlib.axis.YTick at 0x1cd97857438>,
#   <matplotlib.axis.YTick at 0x1cd97863748>,
#   <matplotlib.axis.YTick at 0x1cd97863cc0>,
#   <matplotlib.axis.YTick at 0x1cd9786c278>,
#   <matplotlib.axis.YTick at 0x1cd9786c7f0>,
#   <matplotlib.axis.YTick at 0x1cd9786cd68>,
#   <matplotlib.axis.YTick at 0x1cd97872320>,
#   <matplotlib.axis.YTick at 0x1cd97872898>,
#   <matplotlib.axis.YTick at 0x1cd97872e10>,
#   <matplotlib.axis.YTick at 0x1cd9786cb70>],
#  <a list of 20 Text yticklabel objects>)

# %%
x_rebound = kings_cleansed_df['REB']
y_salary = kings_cleansed_df['SALARY']
plt.scatter(x_rebound,y_salary,marker = 'o',edgecolors = 'purple')
plt.title("Rebounds vs. Salary")
plt.xlabel("Rebounds")
plt.ylabel("Salary")
plt.grid()
plt.yticks(np.arange(0,20000000,1000000))
# Out:
# ([<matplotlib.axis.YTick at 0x1cd97612828>,
#   <matplotlib.axis.YTick at 0x1cd97612160>,
#   <matplotlib.axis.YTick at 0x1cd97608358>,
#   <matplotlib.axis.YTick at 0x1cd9762beb8>,
#   <matplotlib.axis.YTick at 0x1cd976393c8>,
#   <matplotlib.axis.YTick at 0x1cd97639898>,
#   <matplotlib.axis.YTick at 0x1cd97639e10>,
#   <matplotlib.axis.YTick at 0x1cd9763e3c8>,
#   <matplotlib.axis.YTick at 0x1cd9763e940>,
#   <matplotlib.axis.YTick at 0x1cd97639978>,
#   <matplotlib.axis.YTick at 0x1cd9763e7b8>,
#   <matplotlib.axis.YTick at 0x1cd97644198>,
#   <matplotlib.axis.YTick at 0x1cd97644710>,
#   <matplotlib.axis.YTick at 0x1cd97644c88>,
#   <matplotlib.axis.YTick at 0x1cd9764c240>,
#   <matplotlib.axis.YTick at 0x1cd9764c7b8>,
#   <matplotlib.axis.YTick at 0x1cd9764cd30>,
#   <matplotlib.axis.YTick at 0x1cd976532e8>,
#   <matplotlib.axis.YTick at 0x1cd9764c2e8>,
#   <matplotlib.axis.YTick at 0x1cd97644518>],
#  <a list of 20 Text yticklabel objects>)
