# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
#load csv
final = ("../Project_1_Team_7/final_df.csv")
salaries_data = ("../Project_1_Team_7/Players_Salaries.xlsx")

final_df = pd.read_csv(final)
salaries_stats_df = pd.read_excel(salaries_data)
salary_2015_df = pd.read_excel(salaries_data, sheet_name='2015')
salary_2016_df = pd.read_excel(salaries_data, sheet_name='2016')
salary_2017_df = pd.read_excel(salaries_data, sheet_name='2017')
salary_2018_df = pd.read_excel(salaries_data, sheet_name='2018')
salary_2019_df = pd.read_excel(salaries_data, sheet_name='2019')

# %%
final_df.columns
# Out:
# Index(['YEAR', 'PLAYER', 'POSITION', 'TEAM', 'SALARY', 'AGE', 'GP', 'W', 'L',
#        'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%', 'FTM', 'FTA',
#        'FT%', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'PF', 'FP',
#        'DD2', 'TD3', '+/-', 'RK'],
#       dtype='object')

# %%
salaries_stats_df.columns
# Out:
# Index(['RK', 'NAME', 'TEAM', 'SALARY', 'YEAR'], dtype='object')

# %%
#create dataframe for 2015 Clippers salaries
clipper_salary_2015_df = salary_2015_df.loc[salary_2015_df['TEAM'] == "LA Clippers"]
clipper_salary_2015_df.head(5)
# Out:
#       RK               NAME         TEAM    SALARY  YEAR
# 5      6     Chris Paul, PG  LA Clippers  21468695  2015
# 10    11  DeAndre Jordan, C  LA Clippers  19689000  2015
# 14    15  Blake Griffin, PF  LA Clippers  18907726  2015
# 103  104      JJ Redick, SG  LA Clippers   7085000  2015
# 127  128  Jamal Crawford, G  LA Clippers   5675000  2015

# %%
#create dataframe and show 2016 Clippers Salaries
clipper_salary_2016_df = salary_2016_df.loc[salary_2016_df['TEAM'] == "LA Clippers"]
clipper_salary_2016_df.head(5)
# Out:
#     RK               NAME         TEAM    SALARY  YEAR
# 13  14     Chris Paul, PG  LA Clippers  22868827  2016
# 22  23  DeAndre Jordan, C  LA Clippers  21165675  2016
# 27  28  Blake Griffin, PF  LA Clippers  20140839  2016
# 68  69  Jamal Crawford, G  LA Clippers  13253012  2016
# 96  97  Austin Rivers, PG  LA Clippers  11000000  2016

# %%
#create dataframe and show 2017 Clippers Salaries
clipper_salary_2017_df = salary_2017_df.loc[salary_2017_df['TEAM'] == "LA Clippers"]
clipper_salary_2017_df.head(5)
# Out:
#     RK                  NAME         TEAM    SALARY  YEAR
# 1    2     Blake Griffin, PF  LA Clippers  32088932  2017
# 29  30     DeAndre Jordan, C  LA Clippers  22642350  2017
# 35  36  Danilo Gallinari, PF  LA Clippers  20559599  2017
# 64  65     Tobias Harris, SF  LA Clippers  16000000  2017
# 90  91     Austin Rivers, PG  LA Clippers  12650000  2017

# %%
#create dataframe and show 2018 Clippers Salaries
clipper_salary_2018_df = salary_2018_df.loc[salary_2018_df['TEAM'] == "LA Clippers"]
clipper_salary_2018_df.head(5)
# Out:
#       RK                  NAME         TEAM    SALARY  YEAR
# 38    39  Danilo Gallinari, PF  LA Clippers  21587579  2018
# 82    83      Marcin Gortat, C  LA Clippers  13565218  2018
# 146  147      Lou Williams, SG  LA Clippers   8000000  2018
# 172  173     Milos Teodosic, G  LA Clippers   6300000  2018
# 178  179  Montrezl Harrell, PF  LA Clippers   6000000  2018

# %%
#create dataframe and show 2019 Clippers Salaries
clipper_salary_2019_df = salary_2019_df.loc[salary_2019_df['TEAM'] == "LA Clippers"]
clipper_salary_2019_df.head(5)
# Out:
#       RK                  NAME         TEAM    SALARY  YEAR
# 11    12     Kawhi Leonard, SF  LA Clippers  32742000  2019
# 18    19       Paul George, SF  LA Clippers  30560700  2019
# 93    94      Marcin Gortat, C  LA Clippers  13565218  2019
# 112  113  Patrick Beverley, PG  LA Clippers  12345680  2019
# 123  124  Maurice Harkless, SF  LA Clippers  11011234  2019

# %%
#set variables for positions listed on dataset: 
#(G)Guard,(PG)Point Guard,(SG)Shooting Guard,(PF)Power Forward,(SF)Small Forward,(C)Center
point_guard_stats_df = final_df.loc[final_df['POSITION'] == ' PG' ]
guard_stats_df = final_df.loc[final_df['POSITION'] == ' G' ]
shooting_guard_stats_df = final_df.loc[final_df['POSITION'] == ' SG' ]
power_forward_stats_df = final_df.loc[final_df['POSITION'] == ' PF' ]
small_forward_stats_df = final_df.loc[final_df['POSITION'] == ' SF' ]
center_stats_df = final_df.loc[final_df['POSITION'] == ' C' ]

# %%
#create dataframe for Point Guard
point_guard_stats_df = final_df.loc[final_df['POSITION'] == ' PG' ]
point_guard_stats_df
# Out:
#      YEAR              PLAYER POSITION                   TEAM    SALARY  AGE  \
# 0    2015       Stephen Curry       PG  Golden State Warriors  11370786   28
# 31   2016       Stephen Curry       PG  Golden State Warriors  12112359   29
# 34   2017       Stephen Curry       PG  Golden State Warriors  37457154   30
# 36   2017          Quinn Cook       PG  Golden State Warriors   1544951   25
# 48   2018       Stephen Curry       PG  Golden State Warriors  37457154   31
# 50   2018          Quinn Cook       PG  Golden State Warriors   1544951   26
# 74   2019       Stephen Curry       PG  Golden State Warriors  40231758   31
# 79   2015     Jordan Clarkson       PG     Los Angeles Lakers    845059   24
# 95   2016     Jordan Clarkson       PG     Los Angeles Lakers  12500000   25
# 110  2017       Isaiah Thomas       PG     Los Angeles Lakers   6261395   29
# 111  2017     Jordan Clarkson       PG     Los Angeles Lakers  12500000   26
# 115  2017          Lonzo Ball       PG     Los Angeles Lakers   6286560   20
# 132  2018          Lonzo Ball       PG     Los Angeles Lakers   7461960   21
# 134  2018         Rajon Rondo       PG     Los Angeles Lakers   9000000   33
# 149  2019       Avery Bradley       PG     Los Angeles Lakers   4767000   29
# 151  2019         Rajon Rondo       PG     Los Angeles Lakers   2564753   33
# 154  2019          Quinn Cook       PG     Los Angeles Lakers   3000000   26
# 160  2015      Pablo Prigioni       PG            LA Clippers    947726   39
# 170  2015          Chris Paul       PG            LA Clippers  21468695   31
# 173  2015       Austin Rivers       PG            LA Clippers   3110796   23
# 183  2016          Chris Paul       PG            LA Clippers  22868827   32
# 187  2016       Austin Rivers       PG            LA Clippers  11000000   24
# 189  2017       Austin Rivers       PG            LA Clippers  12650000   25
# 190  2017       Avery Bradley       PG            LA Clippers   8808989   27
# 201  2017    Patrick Beverley       PG            LA Clippers   5513514   29
# 187  74  43  31  27.8  ...   2.8  1.6  0.6  0.1  2.5  19.6    0    0  -0.1
# 189  61  30  31  33.7  ...   4.0  1.8  1.2  0.3  2.5  26.5    0    0  -1.0
# 190   6   5   1  27.5  ...   1.8  1.3  0.8  0.2  2.0  18.0    0    0   0.5
# 201  11   5   6  30.3  ...   2.9  2.3  1.7  0.5  3.1  25.7    0    0   2.3
# 208  49  25  24  29.9  ...   2.0  1.2  0.6  0.3  2.7  15.7    0    0  -1.3
# 222  78  48  30  27.4  ...   3.8  1.1  0.9  0.6  3.4  22.5    6    0   1.9
# 232  32  23   9  29.1  ...   3.7  1.3  1.3  0.7  3.3  25.7    4    0   4.2
# 242  20  12   8  10.3  ...   1.0  0.2  0.2  0.0  0.9   5.2    0    0   0.2
# 246  72  29  43  35.2  ...  11.7  3.9  2.0  0.1  2.4  39.1   37    6  -2.1
# 266   2   1   1  17.7  ...   4.5  1.5  1.0  0.0  0.5  16.1    0    0  -0.5
# 286  43  13  30  26.6  ...   2.8  1.4  0.9  0.3  1.7  19.8    0    0  -5.7
# 288  73  24  49  27.7  ...   4.4  2.4  1.0  0.3  2.2  22.8    3    0  -5.7
# 299  81  39  42  31.4  ...   7.3  2.8  1.6  0.6  2.5  36.5   16    1   0.8
# 310  71  33  38  15.0  ...   1.9  0.6  0.5  0.1  0.9  11.8    0    0  -0.8
# 314  40  15  25  25.7  ...   3.6  1.2  0.8  0.4  2.1  17.2    0    0  -1.9
# 315  22   6  16  30.9  ...   7.0  3.5  1.4  0.5  2.9  36.9    5    0  -2.0
# 325  29  11  18  12.8  ...   1.6  0.7  0.3  0.1  0.8   9.4    0    0  -1.3
#
#       RK
# 0     61
# 31    82
# 34     1
# 36   332
# 48     1
# 50   351
# 74     1
# 79   424
# 95    76
# 110  173
# 111   95
# 115  172
# 132  155
# 134  132
# 149  223
# 151  298
# 154  277
# 160  374
# 170    6
# 173  208
# 183   14
# 187   97
# 189   91
# 190  130
# 201  188
# 208  100
# 222  196
# 232  113
# 242  437
# 246   79
# 266  394
# 286   43
# 288  206
# 299  183
# 310  254
# 314  117
# 315  189
# 325  274
#
# [38 rows x 33 columns]

# %%
final_df[["REB","PLAYER"]]
# Out:
#      REB             PLAYER
# 0    5.4      Stephen Curry
# 1    2.2   Shaun Livingston
# 2    3.3  Marreese Speights
# 3    1.7    Leandro Barbosa
# 4    3.8      Klay Thompson
# ..   ...                ...
# 321  6.4    Nemanja Bjelica
# 322  8.5     Richaun Holmes
# 323  4.7       Trevor Ariza
# 324  0.9     Wenyen Gabriel
# 325  1.2       Yogi Ferrell
#
# [326 rows x 2 columns]

# %%
#set PLAYER  index
players_index_df = final_df.set_index("PLAYER")
players_index_df
# Out:
#                    YEAR POSITION                   TEAM    SALARY  AGE  GP  \
# PLAYER
# Stephen Curry      2015       PG  Golden State Warriors  11370786   28  79
# Shaun Livingston   2015        G  Golden State Warriors   5543725   30  78
# Marreese Speights  2015        F  Golden State Warriors   3815000   28  72
# Leandro Barbosa    2015        G  Golden State Warriors   2500000   33  68
# Klay Thompson      2015       SG  Golden State Warriors  15501000   26  80
# ...                 ...      ...                    ...       ...  ...  ..
# Nemanja Bjelica    2019       PF       Sacramento Kings   6825000   31  40
# Richaun Holmes     2019       PF       Sacramento Kings   4767000   26  37
# Trevor Ariza       2019       SF       Sacramento Kings  12195122   34  31
# Wenyen Gabriel     2019        F       Sacramento Kings   1445697   22  11
# Yogi Ferrell       2019       PG       Sacramento Kings   3150000   26  29
#
#                     W   L   MIN   PTS  ...  AST  TOV  STL  BLK   PF    FP  \
# PLAYER                                 ...
# Stephen Curry      71   8  34.2  30.1  ...  6.7  3.3  2.1  0.2  2.0  50.3
# Shaun Livingston   69   9  19.5   6.3  ...  3.0  1.0  0.7  0.3  1.8  15.6
# Marreese Speights  64   8  11.6   7.1  ...  0.8  0.9  0.3  0.5  1.6  13.7
# Leandro Barbosa    60   8  15.9   6.4  ...  1.2  0.8  0.6  0.1  1.6  11.8
# Klay Thompson      71   9  33.3  22.1  ...  2.1  1.7  0.8  0.6  1.9  32.2
# ...                ..  ..   ...   ...  ...  ...  ...  ...  ...  ...   ...
# Nemanja Bjelica    15  25  27.3  12.2  ...  2.5  1.6  0.9  0.6  3.0  26.5
# Richaun Holmes     14  23  29.4  13.1  ...  1.0  1.2  1.1  1.4  3.9  30.9
# Trevor Ariza       12  19  24.9   6.1  ...  1.5  0.9  1.1  0.2  2.0  17.1
# Wenyen Gabriel      2   9   5.6   1.7  ...  0.3  0.5  0.3  0.2  0.6   4.1
# Yogi Ferrell       11  18  12.8   4.8  ...  1.6  0.7  0.3  0.1  0.8   9.4
#
#                    DD2  TD3   +/-   RK
# PLAYER
# Stephen Curry       15    2  12.9   61
# Shaun Livingston     0    0   2.7  132
# Marreese Speights    1    0   0.2  183
# Leandro Barbosa      0    0   0.6  243
# Klay Thompson        0    0  10.5   31
# ...                ...  ...   ...  ...
# Nemanja Bjelica      5    0  -1.3  184
# Richaun Holmes      13    0   0.2  218
# Trevor Ariza         0    0  -1.5  114
# Wenyen Gabriel       0    0  -2.5  434
# Yogi Ferrell         0    0  -1.3  274
#
# [326 rows x 32 columns]

# %%
#highest paid 
highest_paid = final_df.loc[final_df["SALARY"] > 30000000, ["PLAYER","YEAR", "TEAM","POSITION", "PTS","GP","SALARY","REB","AST","TOV","STL","BLK","MIN"]]
highest_paid
# Out:
#             PLAYER  YEAR                   TEAM POSITION   PTS  GP    SALARY  \
# 34   Stephen Curry  2017  Golden State Warriors       PG  26.4  51  37457154
# 48   Stephen Curry  2018  Golden State Warriors       PG  27.3  69  37457154
# 74   Stephen Curry  2019  Golden State Warriors       PG  20.3   4  40231758
# 127   LeBron James  2018     Los Angeles Lakers       SF  27.4  55  35654150
# 145   LeBron James  2019     Los Angeles Lakers       SF  25.5  38  37436858
# 191  Blake Griffin  2017            LA Clippers       PF  22.6  33  32088932
# 230    Paul George  2019            LA Clippers       SF  23.5  26  30560700
# 238  Kawhi Leonard  2019            LA Clippers       SF  25.8  30  32742000
#
#      REB   AST  TOV  STL  BLK   MIN
# 34   5.1   6.1  3.0  1.6  0.2  32.0
# 48   5.3   5.2  2.8  1.3  0.4  33.8
# 74   5.0   6.5  3.8  1.3  0.5  28.0
# 127  8.5   8.3  3.6  1.3  0.6  35.2
# 145  7.8  10.7  3.7  1.3  0.5  34.9
# 191  7.9   5.4  3.0  0.9  0.3  34.5
# 230  6.0   3.7  3.3  1.5  0.5  30.7
# 238  7.5   5.1  3.4  1.9  0.5  32.2

# %%
#highest paid overal nba players
#set with of bar
barWidth = 0.15

#set height of bars
PTS_means = [26.4, 27.3, 20.3, 27.4, 25.5, 22.6, 23.5, 25.8]
GP_means = [51, 69, 4, 55, 38, 33, 26, 30]
MIN_means = [32, 33.8, 28, 35.2, 34.9, 34.5, 30.7, 32.2]
REB_means = [5.1, 5.3, 5.1, 8.5, 7.8, 7.9, 6.0, 7.5]
SALARY = [37, 37, 40, 35, 37, 32, 30, 32]


# the label locations
r1 = np.arange(len(PTS_means))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
# Add xticks on the middle of the group bars

plt.xlabel('group', fontweight='bold')
plt.ylabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(PTS_means))], ['Stephen Curry 2017', 'Stephen Curry 2018', 'Stephen Curry 2019', 'Lebron James 2018', 'Lebron James 2019', 'Blake Griffin 2017', 'Paul George 2019', 'Kawhi Leonard 2019'],rotation=90)
plt.title('Overall Highest Paid NBA Players')

#create group based on highest paid players
plt.xlabel("Players")
plt.ylabel("(Salary in Millions)")
 
#make plot
#highest_paid.plot(r1,highest_paid["SALARY"],kind="bar",figsize=(20,3))

#Plot bar and colors and labels
plt.bar(r1, REB_means, color='blue', width=barWidth, label='Rebounds per Game')
plt.bar(r2, PTS_means, color='orange', width=barWidth, label='Points per Game')
plt.bar(r3, GP_means, color='green', width=barWidth, label='Games per Year')
plt.bar(r4, MIN_means, color='yellowgreen', width=barWidth, label='Minutes per Game')
plt.bar(r5, SALARY, color='red', width=barWidth, label='SALARY in Millions')

plt.legend(bbox_to_anchor=(1, 1, 0.6, 0), loc=2, ncol=1, mode="normal", borderaxespad=1)
plt.show()

# %%
highest_paid = final_df.loc[final_df["SALARY"] > 20000000, ["PLAYER","YEAR", "TEAM","POSITION", "PTS","GP","SALARY","REB","AST","TOV","STL","BLK","MIN"]]
highest_paid
# Out:
#                PLAYER  YEAR                   TEAM POSITION   PTS  GP  \
# 25       Kevin Durant  2016  Golden State Warriors       SF  25.1  62
# 34      Stephen Curry  2017  Golden State Warriors       PG  26.4  51
# 48      Stephen Curry  2018  Golden State Warriors       PG  27.3  69
# 53       Kevin Durant  2018  Golden State Warriors       SF  26.0  78
# 65   D'Angelo Russell  2019  Golden State Warriors       SG  23.7  23
# 74      Stephen Curry  2019  Golden State Warriors       PG  20.3   4
# 81        Kobe Bryant  2015     Los Angeles Lakers       SF  17.6  66
# 113       Brook Lopez  2017     Los Angeles Lakers        C  13.0  74
# 127      LeBron James  2018     Los Angeles Lakers       SF  27.4  55
# 144     Anthony Davis  2019     Los Angeles Lakers       PF  27.1  35
# 145      LeBron James  2019     Los Angeles Lakers       SF  25.5  38
# 170        Chris Paul  2015            LA Clippers       PG  19.5  74
# 182    DeAndre Jordan  2016            LA Clippers        C  12.7  81
# 183        Chris Paul  2016            LA Clippers       PG  18.1  61
# 186     Blake Griffin  2016            LA Clippers       PF  21.6  61
# 191     Blake Griffin  2017            LA Clippers       PF  22.6  33
# 195  Danilo Gallinari  2017            LA Clippers       PF  15.3  21
# 196    DeAndre Jordan  2017            LA Clippers        C  12.0  77
# 210  Danilo Gallinari  2018            LA Clippers       PF  19.8  68
# 230       Paul George  2019            LA Clippers       SF  23.5  26
# 238     Kawhi Leonard  2019            LA Clippers       SF  25.8  30
# 300   Harrison Barnes  2018       Sacramento Kings       SF  14.3  28
# 317   Harrison Barnes  2019       Sacramento Kings       SF  15.2  40
#
#        SALARY   REB   AST  TOV  STL  BLK   MIN
# 25   26540100   8.3   4.8  2.2  1.1  1.6  33.4
# 34   37457154   5.1   6.1  3.0  1.6  0.2  32.0
# 48   37457154   5.3   5.2  2.8  1.3  0.4  33.8
# 53   30000000   6.4   5.9  2.9  0.7  1.1  34.6
# 65   27285000   3.5   6.0  3.0  0.8  0.3  31.5
# 74   40231758   5.0   6.5  3.8  1.3  0.5  28.0
# 81   25000000   3.7   2.8  2.0  0.9  0.2  28.2
# 113  22642650   4.0   1.7  1.3  0.4  1.3  23.4
# 127  35654150   8.5   8.3  3.6  1.3  0.6  35.2
# 144  27093018   9.4   3.2  2.4  1.5  2.6  35.2
# 145  37436858   7.8  10.7  3.7  1.3  0.5  34.9
# 170  21468695   4.2  10.0  2.6  2.1  0.2  32.7
# 182  21165675  13.8   1.2  1.4  0.6  1.7  31.7
# 183  22868827   5.0   9.2  2.4  2.0  0.1  31.5
# 186  20140839   8.1   4.9  2.3  0.9  0.4  34.0
# 191  32088932   7.9   5.4  3.0  0.9  0.3  34.5
# 195  20559599   4.8   2.0  1.2  0.6  0.5  32.0
# 196  22642350  15.2   1.5  1.8  0.5  0.9  31.5
# 210  21587579   6.1   2.6  1.5  0.7  0.3  30.3
# 230  30560700   6.0   3.7  3.3  1.5  0.5  30.7
# 238  32742000   7.5   5.1  3.4  1.9  0.5  32.2
# 300  24107258   5.5   1.9  1.1  0.6  0.1  33.9
# 317  24147727   4.8   2.2  1.3  0.7  0.2  35.1

# %%
#set with of bar
barWidth = 0.15
# Add xticks on the middle of the group bars
plt.title('Highest Paid Clippers Players')
plt.xlabel('group', fontweight='bold')
plt.ylabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(PTS_means))], ['Chris Paul (PG) 2015', "DeAndre Jordan (C) 2016", "Chris Paul (PG) 2016", 'Blake Griffin (PF) 2016', 'Blake Griffin (PF) 2017', 'Danilo Gallinari (PF) 2017', 'DeAndre Jordan (C) 2017', 'Danilo Gallinari (PF) 2018', 'Paul George (SF) 2019', 'Kawhi Leonard (SF) 2019'],rotation=90)


#set height of bars
REB_means = [4.2, 13.8, 5.0, 8.1, 7.9, 4.8, 15.2, 6.1, 6.0, 7.5]
PTS_means = [19.5, 12.7, 18.1, 21.6, 22.6, 15.3, 12.0, 19.8, 23.5, 25.8]
GP_means = [74, 81, 61, 61, 33, 21, 77, 68, 26, 30]
MIN_means = [32.7, 31.7, 31.5, 34.0, 34.5, 32.0, 31.5, 30.3, 30.7, 32.2]
SALARY = [21.4, 21.1, 22.8, 20.1, 32.1, 20.5, 22.6, 21.5, 21.5, 32.7]

# the label locations
r1 = np.arange(len(PTS_means))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]

#create group based on highest paid players
plt.xlabel("Players")
plt.ylabel("(Salary in Millions)")
 
#make plot
#highest_paid.plot(r1,highest_paid["SALARY"],kind="bar",figsize=(20,3))

#Plot bar and colors and labels
plt.bar(r1, REB_means, color='blue', width=barWidth, label='Rebounds per Game')
plt.bar(r2, PTS_means, color='orange', width=barWidth, label='Points per Game')
plt.bar(r3, GP_means, color='green', width=barWidth, label='Games per Year')
plt.bar(r4, MIN_means, color='yellowgreen', width=barWidth, label='Minutes per Game')
plt.bar(r5, SALARY, color='red', width=barWidth, label='SALARY in Millions')

plt.legend(bbox_to_anchor=(1, 1, 0.6, 0), loc=2, ncol=1, mode="normal", borderaxespad=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3efee0804569> in <module>
#       2 barWidth = 0.15
#       3 # Add xticks on the middle of the group bars
# ----> 4 plt.title('Highest Paid Clippers Players')
#       5 plt.xlabel('group', fontweight='bold')
#       6 plt.ylabel('group', fontweight='bold')
#
# NameError: name 'plt' is not defined

# %%
curry_pts = players_index_df.loc[["Stephen Curry","YEAR"]]
print(curry_pts)

# %%
#get avg of Stephen Curry points
curry_pts.mean()

# %%
curry_salary = players_index_df.loc["Stephen Curry","SALARY"]
print(curry_salary)

# %%
#avg of salary s.curry
curry_salary.mean()

# %%
lowest_paid = final_df.loc[final_df["SALARY"] < 600000, ["PLAYER","TEAM","POSITION", "PTS","SALARY","REB","MIN", "GP"]]
lowest_paid
# Out:
#                    PLAYER                   TEAM POSITION   PTS  SALARY  REB  \
# 6          Jason Thompson        Toronto Raptors       PF   2.1  245177  1.9
# 15       Anderson Varejao  Golden State Warriors        C   2.6  289755  2.3
# 18          Briante Weber      Charlotte Hornets        G   1.7  128623  0.6
# 28            Matt Barnes       Sacramento Kings       SF   5.7  242224  4.6
# 29          Patrick McCaw  Golden State Warriors       SG   4.0  543471  1.4
# 60           Andrew Bogut  Golden State Warriors        C   3.5  307648  5.0
# 93            David Nwaba     Los Angeles Lakers        G   6.0   73528  3.2
# 96          Jose Calderon     Los Angeles Lakers        G   3.3  247991  1.8
# 114          Andre Ingram     Los Angeles Lakers        G  12.0   13824  3.0
# 119           Travis Wear     Los Angeles Lakers        F   4.4  148318  2.2
# 125           Nigel Hayes        Toronto Raptors        F   1.5   55296  0.0
# 141        Jemerrio Jones     Los Angeles Lakers        F   4.5   52108  8.2
# 165            Jeff Ayres            LA Clippers        F   1.8  111444  1.3
# 171        Branden Dawson            LA Clippers       SF   0.8  525093  0.7
# 181         Diamond Stone            LA Clippers        C   1.4  543471  0.9
# 194         C.J. Williams            LA Clippers        G   5.5  375000  1.5
# 253            Duje Dukan       Sacramento Kings       PF   6.0  525093  4.0
# 270           Matt Barnes       Sacramento Kings       SF   7.6  242224  5.4
# 271           Omri Casspi       Sacramento Kings        F   5.9  138414  4.1
# 281           Nigel Hayes        Toronto Raptors        F   3.6   55296  4.4
# 285  Georgios Papagiannis       Sacramento Kings        C   2.1  185397  2.3
# 293            BJ Johnson       Sacramento Kings       SF   2.0   42634  0.0
#
#       MIN  GP
# 6     6.4  28
# 15    8.4  22
# 18    6.6   7
# 28   20.5  20
# 29   15.1  71
# 60   12.2  11
# 93   19.9  20
# 96   12.2  24
# 114  32.1   2
# 119  13.4  17
# 125   5.4   2
# 141  23.9   6
# 165   6.3  17
# 171   4.8   6
# 181   3.5   7
# 194  18.6  38
# 253  24.2   1
# 270  25.3  54
# 271  18.0  22
# 281  21.1   5
# 285   7.4  16
# 293   6.1   1

# %%
blake_pts = players_index_df.loc[["Blake Griffin","REB"]]
print(blake_pts)

# %%
#set index to 'Team'
team_df = point_guard_stats_df.set_index("TEAM")
team_df

# %%
#grab only LA Clippers data with .loc
clippers_df = final_df.loc[final_df["TEAM"] == "LA Clippers"]
clippers_df

# %%
#grab only LA Clippers data with .loc
clippers_df = final_df.loc[final_df["PLAYER"] == 'Blake Griffin']
clippers_df

# %%
#stats for Guard position Clippers
# guard_stats_df = players_index_df.loc[players_index_df['POSITION'] == ' G']
# guard_stats_df

# %%
guard_stats_df = players_index_df.loc[players_index_df['POSITION'] == ' G', ["TEAM","POSITION", "PTS","SALARY","REB","MIN", "GP"]]
guard_stats_df.head(10)
# Out:
#                                    TEAM POSITION  PTS   SALARY  REB   MIN  GP
# PLAYER
# Shaun Livingston  Golden State Warriors        G  6.3  5543725  2.2  19.5  78
# Leandro Barbosa   Golden State Warriors        G  6.4  2500000  1.7  15.9  68
# Ian Clark         Golden State Warriors        G  3.6   947276  1.0   8.8  66
# Briante Weber         Charlotte Hornets        G  1.7   128623  0.6   6.6   7
# Ian Clark         Golden State Warriors        G  6.8   980431  1.6  14.8  77
# Shaun Livingston  Golden State Warriors        G  5.1  5782450  2.0  17.7  76
# Shaun Livingston  Golden State Warriors        G  5.5  7692308  1.8  15.9  71
# Nick Young        Golden State Warriors        G  7.3  5192000  1.6  17.4  80
# Shaun Livingston  Golden State Warriors        G  4.0  8307692  1.8  15.1  64
# Nick Young           Los Angeles Lakers        G  7.3  5219169  1.8  19.1  54

# %%
#plot graph for salary correlation to position 'Guard' non clippers
#guard_stats_df


#set with of bar
barWidth = 0.15
# Add xticks on the middle of the group bars
plt.title('Stats for Guards in NBA')
plt.xlabel('group', fontweight='bold')
plt.ylabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(PTS_means))], ['Shaun Livingston (G) 2015', "Leandro Barbosa (G) 2015", "Ian Clark (G) 2015", 'Briante Weber (G) 2016', 'Ian Clark (G) 2016', 'Shaun Livingston (G) 2016', 'Shaun Livingston (G) 2017', 'Nick Young (G) 2017', 'Shaun Livingston (G) 2018', 'Nick Young (G) 2015'],rotation=90)

#set height of bars
REB_means = [2.2, 1.7, 1.0, 0.6, 1.6, 2.0, 1.8, 1.6, 1.8, 1.8]
PTS_means = [6.3, 6.4, 3.6, 1.7, 6.8, 5.1, 5.5, 7.3, 4.0, 7.3]
GP_means = [78, 68, 66, 7, 77, 76, 71, 80, 64, 54]
MIN_means = [19.5, 15.9, 8.8, 6.6, 14.8, 17.7, 15.9, 17.4, 15.1, 19.1]
SALARY = [5.0, 2.5, 0.9, 0.1, 0.9, 5.7, 7.6, 5.1, 8.3, 5.2]

# the label locations
r1 = np.arange(len(PTS_means))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]

#create group based on highest paid players
plt.xlabel("Guard Players")
plt.ylabel("(Millions for Salary)")
 
#make plot
#highest_paid.plot(r1,highest_paid["SALARY"],kind="bar",figsize=(20,3))

#Plot bar and colors and labels
plt.bar(r1, REB_means, color='blue', width=barWidth, label='Rebounds per Game')
plt.bar(r2, PTS_means, color='orange', width=barWidth, label='Points per Game')
plt.bar(r3, GP_means, color='green', width=barWidth, label='Games per Year')
plt.bar(r4, MIN_means, color='yellowgreen', width=barWidth, label='Minutes per Game')
plt.bar(r5, SALARY, color='red', width=barWidth, label='SALARY in Millions')

plt.legend(bbox_to_anchor=(1, 1, 0.6, 0), loc=2, ncol=1, mode="normal", borderaxespad=1)
plt.show()

# %%
guard_stats_df = players_index_df.loc[players_index_df['POSITION'] == ' G',["YEAR","TEAM","POSITION","PTS","SALARY","REB","MIN", "GP"]]
guard_stats_df
# Out:
#                      YEAR                   TEAM POSITION   PTS    SALARY  \
# PLAYER
# Shaun Livingston     2015  Golden State Warriors        G   6.3   5543725
# Leandro Barbosa      2015  Golden State Warriors        G   6.4   2500000
# Ian Clark            2015  Golden State Warriors        G   3.6    947276
# Briante Weber        2016      Charlotte Hornets        G   1.7    128623
# Ian Clark            2016  Golden State Warriors        G   6.8    980431
# Shaun Livingston     2016  Golden State Warriors        G   5.1   5782450
# Shaun Livingston     2017  Golden State Warriors        G   5.5   7692308
# Nick Young           2017  Golden State Warriors        G   7.3   5192000
# Shaun Livingston     2018  Golden State Warriors        G   4.0   8307692
# Nick Young           2015     Los Angeles Lakers        G   7.3   5219169
# David Nwaba          2016     Los Angeles Lakers        G   6.0     73528
# Jose Calderon        2016     Los Angeles Lakers        G   3.3    247991
# Nick Young           2016     Los Angeles Lakers        G  13.2   5443918
# Tyler Ennis          2016     Los Angeles Lakers        G   7.7   1733880
# Andre Ingram         2017     Los Angeles Lakers        G  12.0     13824
# Tyler Ennis          2017     Los Angeles Lakers        G   4.1   1524305
# Lance Stephenson     2018     Los Angeles Lakers        G   7.2   4449000
# Lance Stephenson     2015      Memphis Grizzlies        G   4.7   9000000
# Jamal Crawford       2015            LA Clippers        G  14.2   5675000
# Raymond Felton       2016            LA Clippers        G   6.7    980431
# Jamal Crawford       2016            LA Clippers        G  12.3  13253012
# C.J. Williams        2017            LA Clippers        G   5.5    375000
# Jawun Evans          2017            LA Clippers        G   4.8    815615
# Milos Teodosic       2017            LA Clippers        G   9.5   6000000
# Sean Kilpatrick      2017          Brooklyn Nets        G   4.8   2054856
# Sindarius Thornwell  2017            LA Clippers        G   3.9    815615
# Milos Teodosic       2018            LA Clippers        G   3.2   6300000
# Sindarius Thornwell  2018            LA Clippers        G   1.0   1378242
# Tyrone Wallace       2018            LA Clippers        G   3.5   1349383
# Darren Collison      2015       Sacramento Kings        G  14.0   5013559
# Arron Afflalo        2016       Sacramento Kings        G   8.4  12500000
# Darren Collison      2016       Sacramento Kings        G  13.2   5229454
# Malachi Richardson   2016       Sacramento Kings        G   3.6   1439800
# Ty Lawson            2016       Sacramento Kings        G   9.9    980431
# Tyreke Evans         2016       Sacramento Kings        G  11.6  10203755
# Malachi Richardson   2017        Toronto Raptors        G   3.5   1569360
# Iman Shumpert        2018       Sacramento Kings        G   8.9  11011234
#
#                      REB   MIN  GP
# PLAYER
# Shaun Livingston     2.2  19.5  78
# Leandro Barbosa      1.7  15.9  68
# Ian Clark            1.0   8.8  66
# Briante Weber        0.6   6.6   7
# Ian Clark            1.6  14.8  77
# Shaun Livingston     2.0  17.7  76
# Shaun Livingston     1.8  15.9  71
# Nick Young           1.6  17.4  80
# Shaun Livingston     1.8  15.1  64
# Nick Young           1.8  19.1  54
# David Nwaba          3.2  19.9  20
# Jose Calderon        1.8  12.2  24
# Nick Young           2.3  25.9  60
# Tyler Ennis          1.2  17.8  22
# Andre Ingram         3.0  32.1   2
# Tyler Ennis          1.8  12.7  54
# Lance Stephenson     3.2  16.5  68
# Lance Stephenson     2.5  15.8  43
# Jamal Crawford       1.8  26.9  79
# Raymond Felton       2.7  21.2  80
# Jamal Crawford       1.6  26.3  82
# C.J. Williams        1.5  18.6  38
# Jawun Evans          1.8  16.2  48
# Milos Teodosic       2.8  25.2  45
# Sean Kilpatrick      0.5   9.6   4
# Sindarius Thornwell  1.9  15.8  73
# Milos Teodosic       1.1  10.0  15
# Sindarius Thornwell  0.7   4.9  64
# Tyrone Wallace       1.6  10.1  62
# Darren Collison      2.3  30.0  74
# Arron Afflalo        2.0  25.9  61
# Darren Collison      2.2  30.3  68
# Malachi Richardson   1.0   9.0  22
# Ty Lawson            2.6  25.1  69
# Tyreke Evans         3.6  22.5  14
# Malachi Richardson   1.3  12.7  25
# Iman Shumpert        3.1  26.2  42

# %%
clippers_guard_stats_df = players_index_df.loc[players_index_df['POSITION'] == ' G', ["TEAM", "YEAR", "POSITION", "PTS","SALARY","REB","MIN", "GP"]]
clippers_guard_stats_df
# Out:
#                                       TEAM  YEAR POSITION   PTS    SALARY  \
# PLAYER
# Shaun Livingston     Golden State Warriors  2015        G   6.3   5543725
# Leandro Barbosa      Golden State Warriors  2015        G   6.4   2500000
# Ian Clark            Golden State Warriors  2015        G   3.6    947276
# Briante Weber            Charlotte Hornets  2016        G   1.7    128623
# Ian Clark            Golden State Warriors  2016        G   6.8    980431
# Shaun Livingston     Golden State Warriors  2016        G   5.1   5782450
# Shaun Livingston     Golden State Warriors  2017        G   5.5   7692308
# Nick Young           Golden State Warriors  2017        G   7.3   5192000
# Shaun Livingston     Golden State Warriors  2018        G   4.0   8307692
# Nick Young              Los Angeles Lakers  2015        G   7.3   5219169
# David Nwaba             Los Angeles Lakers  2016        G   6.0     73528
# Jose Calderon           Los Angeles Lakers  2016        G   3.3    247991
# Nick Young              Los Angeles Lakers  2016        G  13.2   5443918
el('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(PTS_means))], ['Jamal Crawford (G) 2015', 'Raymond Felton (G) 2016', 'Jamal Crawford (G) 2016', 'C.J. Williams (G) 2017', 'Jawun Evans (G) 2017', 'Milos Teodosic (G) 2017', 'Sindarius Thornwell (G) 2017', 'Milos Teodosic (G) 2018', 'Sindarius Thornwell (G) 2018', 'Tyrone Wallace (G) 2018'],rotation=90)
#set height of bars
REB_means = [1.8, 2.7, 1.6, 1.5, 1.8, 2.8, 1.9, 1.1, 0.7, 1.6]
PTS_means = [14.2, 6.7, 12.3, 5.5, 4.8, 9.5, 3.9, 3.2, 1.0, 3.5]
GP_means = [79, 80, 82, 38, 48, 45, 73, 15, 64, 62]
MIN_means = [26.9, 21.2, 26.3, 18.6, 16.2, 25.2, 15.8, 10, 4.9, 10.1]
SALARY = [5.6, 0.9, 13.2, 0.3, 0.8, 6, 0.8, 6.3, 1.37, 1.34]

# the label locations
r1 = np.arange(len(PTS_means))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]

#create group based on highest paid players
plt.xlabel("Clippers Guard Stats")
plt.ylabel("(Salary in Millions)")
 
#make plot
#highest_paid.plot(r1,highest_paid["SALARY"],kind="bar",figsize=(20,3))

#Plot bar and colors and labels
plt.bar(r1, REB_means, color='blue', width=barWidth, label='Rebounds per Game')
plt.bar(r2, PTS_means, color='orange', width=barWidth, label='Points per Game')
plt.bar(r3, GP_means, color='green', width=barWidth, label='Games per Year')
plt.bar(r4, MIN_means, color='yellowgreen', width=barWidth, label='Minutes per Game')
plt.bar(r5, SALARY, color='red', width=barWidth, label='SALARY in Millions')

plt.legend(bbox_to_anchor=(1, 1, 0.6, 0), loc=2, ncol=1, mode="normal", borderaxespad=1)
plt.show()

# %%
shooting_guard_stats_df = players_index_df.loc[players_index_df['POSITION'] == ' SG' ,["YEAR","TEAM","POSITION","PTS","SALARY","REB","MIN", "GP"]]
shooting_guard_stats_df.tail(40)
# Out:
#                           YEAR                TEAM POSITION   PTS    SALARY  \
# PLAYER
# Josh Hart                 2018  Los Angeles Lakers       SG   7.8   1655160
# Isaac Bonga               2018  Los Angeles Lakers       SG   0.9   1000000
# Kentavious Caldwell-Pope  2019  Los Angeles Lakers       SG   9.3   8089282
# Danny Green               2019  Los Angeles Lakers       SG   8.7  14634146
# Alex Caruso               2019  Los Angeles Lakers       SG   5.9   2750000
# Troy Daniels              2019  Los Angeles Lakers       SG   4.3   1620564
# Talen Horton-Tucker       2019  Los Angeles Lakers       SG   0.0    898310
# JJ Redick                 2015         LA Clippers       SG  16.3   7085000
# JJ Redick                 2016         LA Clippers       SG  15.0   7377500
# Alan Anderson             2016         LA Clippers       SG   2.9    980431
# Lou Williams              2017         LA Clippers       SG  22.6   7000000
# Garrett Temple            2018   Memphis Grizzlies       SG   4.7   8000000
# Jerome Robinson           2018         LA Clippers       SG   3.4   3046200
# Landry Shamet             2018  Philadelphia 76ers       SG  10.9   1703649
# Lou Williams              2018         LA Clippers       SG  20.0   8000000
# Shai Gilgeous-Alexander   2018         LA Clippers       SG  10.8   3375360
# Terance Mann              2019         LA Clippers       SG   2.2   1000000
# Rodney McGruder           2019         LA Clippers       SG   3.6   4807693
# Lou Williams              2019         LA Clippers       SG  19.8   8000000
# Landry Shamet             2019         LA Clippers       SG   8.3   1995120
# Jerome Robinson           2019         LA Clippers       SG   3.2   3567720
# Seth Curry                2015    Sacramento Kings       SG   6.8    947276
# Marco Belinelli           2015    Sacramento Kings       SG  10.2   6060606
# James Anderson            2015    Sacramento Kings       SG   3.5   1015421
# Ben McLemore              2015    Sacramento Kings       SG   7.8   3156600
# Ben McLemore              2016    Sacramento Kings       SG   8.1   4008882
# Buddy Hield               2016    Sacramento Kings       SG  15.1   3517200
# Garrett Temple            2016    Sacramento Kings       SG   7.8   8000000
# Langston Galloway         2016    Sacramento Kings       SG   6.0   5200000
# Vince Carter              2017    Sacramento Kings       SG   5.4   8000000
# Garrett Temple            2017    Sacramento Kings       SG   8.4   8000000
# Buddy Hield               2017    Sacramento Kings       SG  13.5   3675480
# Bogdan Bogdanovic         2017    Sacramento Kings       SG  11.8   9412280
# Alec Burks                2018           Utah Jazz       SG   1.7  11536515
# Ben McLemore              2018    Sacramento Kings       SG   3.9   5460000
# Bogdan Bogdanovic         2018    Sacramento Kings       SG  14.1   9000000
# Buddy Hield               2018    Sacramento Kings       SG  20.7   3844760
# Bogdan Bogdanovic         2019    Sacramento Kings       SG  14.5   8529386
# Buddy Hield               2019    Sacramento Kings       SG  20.2   4861208
# Justin James              2019    Sacramento Kings       SG   2.9    898310
#
#                           REB   MIN  GP
# PLAYER
# Josh Hart                 3.7  25.6  67
# Isaac Bonga               1.1   5.5  22
# Kentavious Caldwell-Pope  2.1  25.3  40
# Danny Green               3.7  25.3  39
# Alex Caruso               2.0  19.6  37
# Troy Daniels              1.2  11.7  30
# Talen Horton-Tucker       0.0   2.7   2
# JJ Redick                 1.9  28.0  75
# JJ Redick                 2.2  28.2  78
# Alan Anderson             0.8  10.3  30
# Lou Williams              2.5  32.8  79
# Garrett Temple            2.5  19.6  26
# Jerome Robinson           1.2   9.7  33
# Landry Shamet             2.2  27.8  25
# Lou Williams              3.0  26.6  75
# Shai Gilgeous-Alexander   2.8  26.5  82
# Terance Mann              1.0   8.5  24
# Rodney McGruder           2.9  16.6  28
# Lou Williams              3.0  30.4  37
# Landry Shamet             1.9  26.4  23
# Jerome Robinson           1.5  11.3  32
# Seth Curry                1.4  15.7  44
# Marco Belinelli           1.7  24.6  68
# James Anderson            1.7  14.1  51
# Ben McLemore              2.2  21.2  68
# Ben McLemore              2.1  19.3  61
# Buddy Hield               4.1  29.1  25
# Garrett Temple            2.8  26.6  65
# Langston Galloway         1.8  19.7  19
# Vince Carter              2.6  17.7  58
# Garrett Temple            2.3  24.8  65
# Buddy Hield               3.8  25.3  80
# Bogdan Bogdanovic         2.9  27.9  78
# Alec Burks                1.7   9.7  13
# Ben McLemore              0.9   8.3  19
# Bogdan Bogdanovic         3.5  27.8  70
# Buddy Hield               5.0  31.9  82
# Bogdan Bogdanovic         3.0  28.1  30
# Buddy Hield               5.1  34.2  40
# Justin James              1.2   8.7  22

# %%
#plot graph for salary correlation to position 'SG' for clippers
# Shooting Guard positions get paid less 

#set with of bar
barWidth = 0.15
# Add xticks on the middle of the group bars
plt.title('Stats for Shooting Guards for Clippers')
plt.xlabel('group', fontweight='bold')
plt.ylabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(PTS_means))], ['JJ Redick (SG) 2015', 'JJ Redick (SG) 2016', 'Alan Anderson (SG) 2016', 'Lou Williams (SG) 2017', 'Jerome Robinson (SG) 2018', 'Lou Williams (SG) 2018', 'Shai Gilgeous-Alexander (SG) 2018', 'Terance Mann (SG) 2019', 'Rodney McGruder (SG) 2019', 'Lou Williams (SG) 2019'],rotation=90)

#set height of bars
REB_means = [1.9, 2.2, 0.8, 2.5, 2.5, 1.2, 2.2, 3.0, 2.8, 1.0]
PTS_means = [16.3, 15.0, 2.9, 22.6, 3.4, 20, 10.8, 2.2, 3.6, 19.8]
GP_means = [75, 78, 30, 79, 33, 75, 82, 24, 28, 37]
MIN_means = [28, 28.2, 10.3, 32.8, 9.7, 26.6, 26.5, 8.5, 16.6, 30.4]
SALARY = [7.08, 7.37, 0.98, 7, 3.04, 8.0, 3.37, 1, 4.8, 8]

# the label locations
r1 = np.arange(len(PTS_means))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]

#create group based on highest paid players
plt.xlabel("Shooting Guard Clippers")
plt.ylabel("(Millions for Salary)")
 
#make plot
#highest_paid.plot(r1,highest_paid["SALARY"],kind="bar",figsize=(20,3))

#Plot bar and colors and labels
plt.bar(r1, REB_means, color='blue', width=barWidth, label='Rebounds per Game')
plt.bar(r2, PTS_means, color='orange', width=barWidth, label='Points per Game')
plt.bar(r3, GP_means, color='green', width=barWidth, label='Games per Year')
plt.bar(r4, MIN_means, color='yellowgreen', width=barWidth, label='Minutes per Game')
plt.bar(r5, SALARY, color='red', width=barWidth, label='SALARY in Millions')

plt.legend(bbox_to_anchor=(1, 1, 0.6, 0), loc=2, ncol=1, mode="normal", borderaxespad=1)
plt.show()

# %%
power_forward_stats_df = players_index_df.loc[players_index_df['POSITION'] == ' PF' ,["YEAR","TEAM","POSITION","PTS","SALARY","REB","MIN", "GP"]]
power_forward_stats_df
# Out:
#                    YEAR                   TEAM POSITION   PTS    SALARY   REB  \
# PLAYER
# Kevon Looney       2015  Golden State Warriors       PF   1.8   1131960   2.0
# Jason Thompson     2015        Toronto Raptors       PF   2.1    245177   1.9
# Draymond Green     2015  Golden State Warriors       PF  14.0  14260870   9.5
# Draymond Green     2016  Golden State Warriors       PF  10.2  15330435   7.9
# Kevon Looney       2016  Golden State Warriors       PF   2.5   1182840   2.3
# Kevon Looney       2017  Golden State Warriors       PF   4.0   1471382   3.3
# Jordan Bell        2017  Golden State Warriors       PF   4.6   1378242   3.6
# Draymond Green     2017  Golden State Warriors       PF  11.0  17469565   7.6
# Kevon Looney       2018  Golden State Warriors       PF   6.3   1512601   5.2
# Jordan Bell        2018  Golden State Warriors       PF   3.3   1378242   2.7
el('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(PTS_means))], ['Blake Griffin (PF) 2016', 'Blake Griffin (PF) 2017', 'Danilo Gallinari (PF) 2017', 'Montrezl Harrell (PF) 2017', 'Danilo Gallinari (PF) 2018', 'Montrezi Harrell (PF) 2018', 'Patrick Patterson (PF) 2019', 'Montrezl Harrell (PF) 2019', 'Mfiondu Kabenge (PF) 2019', 'JaMychal Green (PF) 2019'],rotation=90)

#set height of bars
REB_means = []
PTS_means = [21.6, 22.6, 15.3, 11, 19.8, 16.6, 5.1, 19.3, 2.9, 6.9]
GP_means = [61, 33, 21, 76, 68, 82, 35, 39, 10, 31]
MIN_means = [34, 34.5, 32, 17, 30.3, 26.3, 14.1, 29.2, 4.4, 21.2]
SALARY = [20.1, 32.08, 20.55, 1.4, 21.5, 6, 1.6, 6, 1.97, 4.76]

# the label locations
r1 = np.arange(len(PTS_means))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]


#create group based on highest paid players
plt.xlabel("Power Forward Players")
plt.ylabel("(Millions for Salary)")
 
#make plot
#highest_paid.plot(r1,highest_paid["SALARY"],kind="bar",figsize=(20,3))

#Plot bar and colors and labels
plt.bar(r1, REB_means, color='blue', width=barWidth, label='Rebounds per Game')
plt.bar(r2, PTS_means, color='orange', width=barWidth, label='Points per Game')
plt.bar(r3, GP_means, color='green', width=barWidth, label='Games per Year')
plt.bar(r4, MIN_means, color='yellowgreen', width=barWidth, label='Minutes per Game')
plt.bar(r5, SALARY, color='red', width=barWidth, label='SALARY in Millions')

plt.legend(bbox_to_anchor=(1, 1, 0.6, 0), loc=2, ncol=1, mode="normal", borderaxespad=1)
plt.show()

# %%
small_forward_stats_df = players_index_df.loc[players_index_df['POSITION'] == ' SF' ,["YEAR","TEAM","POSITION","PTS","SALARY","REB","MIN", "GP"]]
small_forward_stats_df
# Out:
#                       YEAR                   TEAM POSITION   PTS    SALARY  \
# PLAYER
# James Michael McAdoo  2015  Golden State Warriors       SF   2.9    845059
# Harrison Barnes       2015  Golden State Warriors       SF  11.7   3873398
# James Michael McAdoo  2016  Golden State Warriors       SF   2.8    980431
# Kevin Durant          2016  Golden State Warriors       SF  25.1  26540100
# Matt Barnes           2016       Sacramento Kings       SF   5.7    242224
# Kevin Durant          2018  Golden State Warriors       SF  26.0  30000000
# Alfonzo McKinnie      2018  Golden State Warriors       SF   4.7   1349383
# Glenn Robinson III    2019  Golden State Warriors       SF  12.2   1620564
# Kobe Bryant           2015     Los Angeles Lakers       SF  17.6  25000000
# Metta World Peace     2015     Los Angeles Lakers       SF   5.0    947276
# Brandon Ingram        2016     Los Angeles Lakers       SF   9.4   5281680
# Metta World Peace     2016     Los Angeles Lakers       SF   2.3    980431
# Brandon Ingram        2017     Los Angeles Lakers       SF  16.1   5519400
# LeBron James          2018     Los Angeles Lakers       SF  27.4  35654150
# Brandon Ingram        2018     Los Angeles Lakers       SF  18.3   5757120
# Moritz Wagner         2018     Los Angeles Lakers       SF   4.8   1762080
# LeBron James          2019     Los Angeles Lakers       SF  25.5  37436858
# Jared Dudley          2019     Los Angeles Lakers       SF   1.6   1620564
# Paul Pierce           2015            LA Clippers       SF   6.1   3376000
# Branden Dawson        2015            LA Clippers       SF   0.8    525093
# Paul Pierce           2016            LA Clippers       SF   3.2   3527920
# Tobias Harris         2017            LA Clippers       SF  19.3  16000000
# Tobias Harris         2018     Philadelphia 76ers       SF  20.9  14800000
el('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(PTS_means))], ['Paul Pierce (SF) 2015', 'Branden Dawson (SF) 2015', 'Paul Pierce (SF) 2016', 'Tobias Harris (SF) 2017', 'Paul George (SF) 2019', 'Maurice Harkless (SF) 2019', 'Kawhi Leonard (SF) 2019'],rotation=90)

#set height of bars
REB_means = [2.7, 0.7, 1.9, 6.0, 6.1, 3.8, 7.5]
PTS_means = [6.1, 0.8, 3.2, 19.3, 23.5, 5.7, 25.8]
GP_means = [68, 6, 25, 32, 26, 40, 30]
MIN_means = [18.1, 4.8, 11.1, 34.5, 30.7, 22.9, 32.2]
SALARY = [3.37, 0.5, 3.5, 16, 30.5, 11, 32.7]

# the label locations
r1 = np.arange(len(PTS_means))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]

#create group based on highest paid players
plt.xlabel("Small Forward Players")
plt.ylabel("(Millions for Salary)")
 
#make plot
#highest_paid.plot(r1,highest_paid["SALARY"],kind="bar",figsize=(20,3))

#Plot bar and colors and labels
plt.bar(r1, REB_means, color='blue', width=barWidth, label='Rebounds per Game')
plt.bar(r2, PTS_means, color='orange', width=barWidth, label='Points per Game')
plt.bar(r3, GP_means, color='green', width=barWidth, label='Games per Year')
plt.bar(r4, MIN_means, color='yellowgreen', width=barWidth, label='Minutes per Game')
plt.bar(r5, SALARY, color='red', width=barWidth, label='SALARY in Millions')

plt.legend(bbox_to_anchor=(1, 1, 0.6, 0), loc=2, ncol=1, mode="normal", borderaxespad=1)
plt.show()

# %%
center_stats_df = players_index_df.loc[players_index_df['POSITION'] == ' C' ,["YEAR","TEAM","POSITION","PTS","SALARY","REB","MIN", "GP"]]
center_stats_df
# Out:
#                       YEAR                   TEAM POSITION   PTS    SALARY  \
# PLAYER
# Festus Ezeli          2015  Golden State Warriors        C   7.0   2008748
# Andrew Bogut          2015  Golden State Warriors        C   5.4  13800000
# Anderson Varejao      2015  Golden State Warriors        C   2.6    289755
# Anderson Varejao      2016  Golden State Warriors        C   1.3    980431
# Damian Jones          2016  Golden State Warriors        C   1.9   1171560
# JaVale McGee          2016  Golden State Warriors        C   6.1   1403611
# Zaza Pachulia         2016  Golden State Warriors        C   6.1   2898000
# Zaza Pachulia         2017  Golden State Warriors        C   5.4   3477600
# JaVale McGee          2017  Golden State Warriors        C   4.8   1471382
# Damian Jones          2017  Golden State Warriors        C   1.7   1312611
# DeMarcus Cousins      2018  Golden State Warriors        C  16.3   5337000
# Damian Jones          2018  Golden State Warriors        C   5.4   1544951
# Andrew Bogut          2018  Golden State Warriors        C   3.5    307648
# Willie Cauley-Stein   2019  Golden State Warriors        C   7.8   2177483
# Robert Sacre          2015     Los Angeles Lakers        C   3.5    981348
# Roy Hibbert           2015     Los Angeles Lakers        C   5.9  15592217
# Tarik Black           2015     Los Angeles Lakers        C   3.4    845059
# Ivica Zubac           2016     Los Angeles Lakers        C   7.5   1034956
# Tarik Black           2016     Los Angeles Lakers        C   5.7   6191000
# Timofey Mozgov        2016     Los Angeles Lakers        C   7.4  16000000
# Brook Lopez           2017     Los Angeles Lakers        C  13.0  22642650
# Ivica Zubac           2017     Los Angeles Lakers        C   3.7   1312611
# Andrew Bogut          2017     Los Angeles Lakers        C   1.5   1471382
# Thomas Bryant         2017     Los Angeles Lakers        C   1.5    815615
# JaVale McGee          2018     Los Angeles Lakers        C  12.0   1512601
# Ivica Zubac           2018     Los Angeles Lakers        C   8.5   1544951
# DeAndre Jordan        13.8  31.7  81
# Boban Marjanovic       4.4   8.3  20
# DeAndre Jordan        15.2  31.5  77
# Willie Reed            3.1  10.7  39
# Boban Marjanovic       4.2  10.4  36
# Ivica Zubac            7.7  20.1  26
# Marcin Gortat          5.6  16.0  47
# Ivica Zubac            6.8  17.3  40
# Willie Cauley-Stein    5.3  21.4  66
# Kosta Koufos           5.4  19.0  78
# Eric Moreland          1.4   5.9   8
# DeMarcus Cousins      11.5  34.6  65
# DeMarcus Cousins      10.6  34.4  55
# Georgios Papagiannis   3.9  16.1  22
# Kosta Koufos           5.7  20.0  71
# Willie Cauley-Stein    4.5  18.9  75
# Willie Cauley-Stein    7.0  28.0  73
# Kosta Koufos           6.6  19.6  71
# Georgios Papagiannis   2.3   7.4  16
# Kosta Koufos           4.2  11.9  42
# Willie Cauley-Stein    8.4  27.3  81
# Dewayne Dedmon         4.0  13.8  26

# %%
#plot graph for salary correlation to position 'C' for clippers
# Center positions 

#set with of bar
barWidth = 0.15
# Add xticks on the middle of the group bars
plt.title('Centers for Clippers')
plt.xlabel('group', fontweight='bold')
plt.ylabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(PTS_means))], ['DeAndre Jordan (C) 2015', 'Cole Aldrich (C) 2015', 'Diamond Stone (C) 2016', 'DeAndre Jordan (C) 2016', 'Boban Marjanovic (C) 2017', 'DeAndre Jordan (C) 2017', 'Willie Reed (C) 2017', 'Marcin Gortat (C) 2018', 'Ivica Zubac (C) 2019'],rotation=90)

#set height of bars
REB_means = [13.8, 4.8, 0.9, 13.8, 4.4, 15.2, 3.1, 5.6, 6.8]
PTS_means = [12.7, 5.5, 1.4, 12.7, 5.9, 12, 4.9, 5, 8.2]
GP_means = [77, 60, 7, 81, 20, 77, 39, 47, 40]
MIN_means = [33.7, 13.3, 3.5, 31.7, 8.3, 31.5, 10.7, 16, 17.3]
SALARY = [19.6, 1.1, 0.54, 21.1, 7, 22.6, 1.47, 13.5, 6.4]

# the label locations
r1 = np.arange(len(PTS_means))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]


#create group based on highest paid players
plt.xlabel("Centers Players")
plt.ylabel("(Millions for Salary)")
 
#make plot
#highest_paid.plot(r1,highest_paid["SALARY"],kind="bar",figsize=(20,3))

#Plot bar and colors and labels
plt.bar(r1, REB_means, color='blue', width=barWidth, label='Rebounds per Game')
plt.bar(r2, PTS_means, color='orange', width=barWidth, label='Points per Game')
plt.bar(r3, GP_means, color='green', width=barWidth, label='Games per Year')
plt.bar(r4, MIN_means, color='yellowgreen', width=barWidth, label='Minutes per Game')
plt.bar(r5, SALARY, color='red', width=barWidth, label='SALARY in Millions')

plt.legend(bbox_to_anchor=(1, 1, 0.6, 0), loc=2, ncol=1, mode="normal", borderaxespad=1)
plt.show()

# %%
point_guard_stats_df = players_index_df.loc[players_index_df['POSITION'] == ' PG' ,["YEAR","TEAM","POSITION","PTS","SALARY","REB","MIN", "GP"]]
point_guard_stats_df
# Out:
#                     YEAR                   TEAM POSITION   PTS    SALARY  REB  \
# PLAYER
# Stephen Curry       2015  Golden State Warriors       PG  30.1  11370786  5.4
# Jordan Clarkson     23.7  53
# Lonzo Ball          34.2  52
# Lonzo Ball          30.3  47
# Rajon Rondo         29.8  46
# Avery Bradley       23.8  26
# Rajon Rondo         21.6  27
# Quinn Cook          12.8  26
# Pablo Prigioni      13.9  59
# Chris Paul          32.7  74
# Austin Rivers       21.8  67
# Chris Paul          31.5  61
# Austin Rivers       27.8  74
# Austin Rivers       33.7  61
# Avery Bradley       27.5   6
# Patrick Beverley    30.3  11
# Avery Bradley       29.9  49
# Patrick Beverley    27.4  78
# Patrick Beverley    29.1  32
# Derrick Walton Jr.  10.3  20
# Rajon Rondo         35.2  72
# Jordan Farmar       17.7   2
# George Hill         26.6  43
# De'Aaron Fox        27.7  73
# De'Aaron Fox        31.4  81
# Yogi Ferrell        15.0  71
# Cory Joseph         25.7  40
# De'Aaron Fox        30.9  22
# Yogi Ferrell        12.8  29

# %%
#plot graph for salary correlation to position 'PG' for clippers
# Point Guards positions 

#set with of bar
barWidth = 0.15
# Add xticks on the middle of the group bars
plt.title('Point Guards for Clippers')
plt.xlabel('group', fontweight='bold')
plt.ylabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(PTS_means))], ['Pablo Prigioni (PG) 2015', 'Chris Paul (PG) 2015', 'Austin Rivers (PG) 2015', 'Chris Paul (PG) 2016', 'Austin Rivers (PG) 2016', 'Austin Rivers (PG) 2017', 'Avery Bradley (PG) 2017', 'Patrick Beverly (PG) 2017', 'Patrick Beverley (PG) 2018', 'Patrick Beverley (PG) 2019', 'Derrick Walton, Jr. (PG) 2019'],rotation=90)

#set height of bars
REB_means = [1.9, 4.2, 1.9, 5.0, 2.2, 2.4, 3.7, 4.1, 5.0, 6.2, 0.7 ]
PTS_means = [2.5, 19.5, 8.9, 18.1, 12, 15.1, 9.2, 12.2, 7.6, 8.1, 2.5]
GP_means = [59, 74, 67, 61, 74, 61, 6, 11, 78, 32, 20]
MIN_means = [13.9, 32.7, 21.8, 31.5, 27.8, 33.7, 27.5, 30.3, 27.4, 29.1, 10.3]
SALARY = [0.9, 21.4, 3.1, 22.8, 11, 12.6, 8.8, 5.5, 5, 12.3, 1.4]

# the label locations
r1 = np.arange(len(PTS_means))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]


#create group based on highest paid players
plt.xlabel("Point Guards Players")
plt.ylabel("(Millions for Salary)")
 
#make plot
#highest_paid.plot(r1,highest_paid["SALARY"],kind="bar",figsize=(20,3))

#Plot bar and colors and labels
plt.bar(r1, REB_means, color='blue', width=barWidth, label='Rebounds per Game')
plt.bar(r2, PTS_means, color='orange', width=barWidth, label='Points per Game')
plt.bar(r3, GP_means, color='green', width=barWidth, label='Games per Year')
plt.bar(r4, MIN_means, color='yellowgreen', width=barWidth, label='Minutes per Game')
plt.bar(r5, SALARY, color='red', width=barWidth, label='SALARY in Millions')

plt.legend(bbox_to_anchor=(1, 1, 0.6, 0), loc=2, ncol=1, mode="normal", borderaxespad=1)
plt.show()

# %%
! jupyter nbconvert --to script Clippers_ha.ipynb
# Out:
# [NbConvertApp] Converting notebook Clippers_ha.ipynb to script
# [NbConvertApp] Writing 22192 bytes to Clippers_ha.py
