# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# %%
cleansed_df = pd.read_csv('cleaned_df.csv')

# %%
mean, sigma = np.mean(cleansed_df['PTS']), np.std(cleansed_df['PTS'])

# conf_int = stats.norm.interval(0.68, loc=mean, 
#     scale=sigma)
conf_int = stats.norm.interval(0.68, loc=mean, 
    scale=sigma / np.sqrt(len(cleansed_df['PTS'])))
conf_int
# Out:
# (8.91689608476475, 9.644946020498407)

# %%
cleansed_df
lakers_cleansed_df = cleansed_df.loc[cleansed_df['TEAM']== 'Los Angeles Lakers'] 
goldenstate_cleansed_df = cleansed_df.loc[cleansed_df['TEAM']== 'Golden State warriors'] 
laclippers_cleansed_df = cleansed_df.loc[cleansed_df['TEAM']== 'LA Clippers']
kings_df = cleansed_df.loc[cleansed_df['TEAM']== 'Sacramento Kings']

# %%
lakers_cleansed_df
# Out:
#     YEAR               PLAYER                   TEAM    SALARY  AGE  GP   W  \
# 0   2015        Stephen Curry  Golden State Warriors  11370786   28  79  71
# 1   2015     Shaun Livingston  Golden State Warriors   5543725   30  78  69
# 2   2015    Marreese Speights  Golden State Warriors   3815000   28  72  64
# 3   2015      Leandro Barbosa  Golden State Warriors   2500000   33  68  60
# 4   2015        Klay Thompson  Golden State Warriors  15501000   26  80  71
# ..   ...                  ...                    ...       ...  ...  ..  ..
# 69  2019         Kevon Looney  Golden State Warriors   4464226   23  10   3
# 70  2019      Marquese Chriss  Golden State Warriors   1620564   22  37   9
# 71  2019       Omari Spellman  Golden State Warriors   1897800   22  38   8
# 72  2019        Stephen Curry  Golden State Warriors  40231758   31   4   1
# 73  2019  Willie Cauley-Stein  Golden State Warriors   2177483   26  36   8
#
# ...

# %%
count = len(lakers_cleansed_df)
count
# Out:
# 79

# %%
lakers_cleansed_df_corr = lakers_cleansed_df.corr()
corr_lakers_df = lakers_cleansed_df_corr.unstack().sort_values()
corr_lakers_df.to_csv('lakers_corr.csv', header=True)

cleansed_df_corr = cleansed_df.corr()
corr_df = cleansed_df_corr.unstack().sort_values()
corr_df.to_csv('corr.csv', header=True)

laclippers_cleansed_df_corr = cleansed_df.corr()
corr_laclippers_df = laclippers_cleansed_df_corr.unstack().sort_values()
corr_laclippers_df.to_csv('laclippers_corr.csv', header=True)

kings_cleansed_df_corr = cleansed_df.corr()
corr_kings_df = cleansed_df_corr.unstack().sort_values()
corr_kings_df.to_csv('kings_corr.csv', header=True)

goldenstate_cleansed_df_corr = cleansed_df.corr()
corr_goldenstate_df = goldenstate_cleansed_df_corr.unstack().sort_values()
corr_goldenstate_df.to_csv('goldenstate_corr.csv', header=True)

# %%
def mylinreg(x_values,y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(6,10),fontsize=15,color="red")
    print(f"The r-squared is: {rvalue}")

# %%
x_Lat = city_weather_df['Lat']
y_windspeed = city_weather_df['Wind Speed']
plt.scatter(x_Lat,y_windspeed,marker = 'o',edgecolors = 'black')
plt.title("City Latitude vs. Wind Speed (01/15/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.yticks(np.arange(0,50,10))
